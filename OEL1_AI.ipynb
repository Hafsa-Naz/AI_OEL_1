# %% [markdown]
# OEL 1
# 23F_AI_56

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Part 1: Data Handling with Pandas

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/shelter.DATASET/shelter_data.csv")
df
# Out:
#   shelter_id     shelter_name  capacity
# 0         S1    Alpha Shelter       200
# 1         S2     Beta Shelter       150
# 2         S3    Delta Shelter       300
# 3         S4     Echo Shelter       100
# 4         S5  Foxtrot Shelter       250

# %%
shelter_capacity_greater_than_200=df[df['capacity']<200]
shelter_capacity_greater_than_200
# Out:
#   shelter_id  shelter_name  capacity
# 1         S2  Beta Shelter       150
# 3         S4  Echo Shelter       100

# %%
shelter_highest_capacity=df.sort_values('capacity',ascending=False).head(1)
shelter_highest_capacity
# Out:
#   shelter_id   shelter_name  capacity
# 2         S3  Delta Shelter       300

# %% [markdown]
# Part 2: Graph **Representation**

# %%
roads = {
 'S1': ['S2', 'S3'],
 'S2': ['S1', 'S4'],
 'S3': ['S1', 'S5'],
 'S4': ['S2'],
 'S5': ['S3']
}
roads
# Out:
# {'S1': ['S2', 'S3'],
#  'S2': ['S1', 'S4'],
#  'S3': ['S1', 'S5'],
#  'S4': ['S2'],
#  'S5': ['S3']}

# %% [markdown]
# Part 3: Implement BFS

# %%
from collections import deque

def find_reachable_shelters(roads, start):
    visited = []
    queue = deque([start])

    while queue:
        current = queue.popleft()
        if current not in visited:
            visited.append(current)
            for neighbor in roads[current]:
                if neighbor not in visited:
                    queue.append(neighbor)

    return visited


shelters = find_reachable_shelters(roads, 'S4')
print(shelters)
# Out:
# ['S4', 'S2', 'S1', 'S3', 'S5']

# %% [markdown]
# Bonus Task: Integrated Analysis

# %%
reachable_shelters_capacity_greater_20=df[df['capacity']>200]
reachable_shelters_capacity_greater_20
# Out:
#   shelter_id     shelter_name  capacity
# 2         S3    Delta Shelter       300
# 4         S5  Foxtrot Shelter       250
